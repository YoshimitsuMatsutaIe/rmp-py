# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("res.csv")
df2 = pd.read_csv("res_thanos.csv")

# %%
fig = plt.figure(figsize=(19, 8))
ax = fig.add_subplot(111)
ax.plot(df["obs"], df["none_par_cpu"], label="none_par_cpu", marker="o")
ax.plot(df["obs"], df["none_par_real"], label="none_par_real", marker="o")
# ax.plot(df["obs"], df["par_cpu"], label="par_cpu", marker="o")
# ax.plot(df["obs"], df["par_real"], label="par_real", marker="o")
ax.plot(df2["obs"], df2["none_par_cpu"], label="none_par_cpu_thanos", marker="o")
ax.plot(df2["obs"], df2["none_par_real"], label="none_par_real_thanos", marker="o")
# ax.plot(df2["obs"], df2["par_cpu"], label="par_cpu_thanos", marker="o")
# ax.plot(df2["obs"], df2["par_real"], label="par_real_thanos", marker="o")
ax.legend()
#ax.set_aspect("equal")
ax.grid()
